# %%
from docx import Document
import re
import pandas as pd

# %%
nama_file = 'Contoh_100an_soal'


doc = Document(f'{nama_file}.docx')
columns_soal = ['Soal-soal', 'A', 'B', 'C', 'D', 'E']
T_soal_soal = pd.DataFrame(columns=columns_soal)

simbol_soal = "."
count = 0
count_n = 0
numbers = []
for i in doc.paragraphs:
    if re.match(f'^\d+\{simbol_soal}', i.text):
        T_soal_soal.loc[count, 'Soal-soal'] = i.text[3:]
        count += 1
        count_n += 1
        numbers.append(i.text[3:])
    elif re.match('^\D+\.', i.text):
        if re.match('^[Aa]\.', i.text):
            T_soal_soal.loc[(count-1), 'A'] = i.text[3:]
        elif re.match('^[Bb]\.', i.text):
            T_soal_soal.loc[(count-1), 'B'] = i.text[3:]
        elif re.match('^[Cc]\.', i.text):
            T_soal_soal.loc[(count-1), 'C'] = i.text[3:]
        elif re.match('^[Dd]\.', i.text):
            T_soal_soal.loc[(count-1), 'D'] = i.text[3:]
        elif re.match('^[Ee]\.', i.text):
            T_soal_soal.loc[(count-1), 'E'] = i.text[3:]
    elif re.match('^[Jj][Aa][Ww][Aa][Bb][Aa][Nn]', i.text) or re.match('^[Jj][Aa][Ww][Aa][Bb]', i.text):
        # print(i.text)
        pass
    elif re.match('^\D+', i.text):
        T_soal_soal.loc[count-1, 'Soal-soal'] = str(numbers[(count_n-1)]) + "\n" + i.text
        numbers.append(T_soal_soal.loc[count-1, 'Soal-soal'] + " ")
        count_n += 1

T_soal_soal.index = T_soal_soal.index +1
T_soal_soal.to_excel(f'{nama_file}.xlsx', engine='openpyxl')

T_soal_soal
# Out:
#                                             Soal-soal                     A  \
# 1   Membaca intensif merupakan kegiatan membaca su...           Sambil lalu
# 2     Kalimat utama biasanya terdapat pada tiap .....                  Kata
# 3   Rencana kerja yang memuat garis – garis besar ...         Tema karangan
# 4                Kegemaran sama artinya dengan ......  Sesuatu yang disukai
# 5   Berikut ini bukan kegemaran yang biasa dilakuk...                  Bola
# ..                                                ...                   ...
# 95   Baris pertama dan kedua pada pantun merupakan...                   Isi
# 96                Ciri – ciri pantun bersajak .......               a-a-b-b
# 97   Persamaan bunyi pada akhir baris pantun diseb...                 Bait
# 98          Tiap bait pada pantun terdiri atas ......             Dua baris
# 99   Dian gemar sekali membaca buku, sehingga ia d...             Kutu buku
#
#                         B                       C  \
# 1                 Sekilas                Mendalam
# 2                Paragraf                 Kalimat
# 3       Kerangka karangan          Topik karangan
# 4   Hal yang menyenangkan  Kegiatan sehari – hari
# 5                Kelereng         Layang – layang
# ..                    ...                     ...
# 95               Sampiran                    Tema
# 96                a-b-b-a                 b-a-a-b
# 97                   Rima                  Baris
# 98             Tiga baris             Empat baris
# 99          Kolektor buku          Pengarang buku
#
#                                    D    E
# 1                              teori  NaN
# 2                          Suku kata  NaN
# 3                     Judul karangan  NaN
# 4   Kegiatan menghilangkan kejenuhan  NaN
# 5                             Boneka  NaN
# ..                               ...  ...
# 95                     Gagasan pokok  NaN
# 96                           a-b-a-b  NaN
# 97                             Ritme  NaN
# 98                        Lima baris  NaN
# 99                    Pengusaha buku  NaN
#
# [99 rows x 6 columns]
